# %%
import pandas as pd

# %% [markdown]
# # 1.	Write a Pandas program to compare the elements of two Pandas series. Sample Series [4,65,436,3,9], [7,0,3,897,9]

# %%
series1 = pd.Series([4,65,436,3,9])
series2 = pd.Series([7,0,3,897,9])

series1.compare(series2)
# Out:
#     self  other
# 0    4.0    7.0
# 1   65.0    0.0
# 2  436.0    3.0
# 3    3.0  897.0

# %% [markdown]
# # 2.	Write a Pandas program to add, subtract, multiply and divide two Pandas series.  Sample Series: [2,4,6,8,14], [1,3,5,7,9]

# %%
series1 = pd.Series([2,4,6,8,14])
series2 = pd.Series([1,3,5,7,9])

#addition
print("Addition")
addition = series1 + series2
print(addition)

#subtraction
print("subtraction")
subtraction = series1 - series2
print(subtraction)

#multiplication
print("Multiplication")
multiplcation = series1 * series2
print(multiplcation)

#division
print("Division")
division = series1 / series2
print(division)
# Out:
# Addition
# 0     3
# 1     7
# 2    11
# 3    15
# 4    23
# dtype: int64
# subtraction
# 0    1
# 1    1
# 2    1
# 3    1
# 4    5
# dtype: int64
# Multiplication
# 0      2
# 1     12
# 2     30
# 3     56
# 4    126
# dtype: int64
# Division
# 0    2.000000
# 1    1.333333
# 2    1.200000
# 3    1.142857
# 4    1.555556
# dtype: float64

# %% [markdown]
# # 3.	Write a Pandas program to convert a dictionary to a Pandas series. Sample dictionary: dictionary1 = {"Josh: 24, ‘Sam’: 36, ‘Peace’: 19, ‘Charles’: 65, ‘Tom’: 44}

# %%
dictionary1 = {"Josh": 24, "Sam" : 36, "Peac": 19, "Chares": 65, "Tom" : 44}
pd.Series(dictionary1)
# Out:
# Josh      24
# Sam       36
# Peac      19
# Chares    65
# Tom       44
# dtype: int64

# %% [markdown]
# # 4.	Write a Pandas program to convert a given series to an array. Sample series: ['Love’, 800, ‘Joy’, 789.9, ‘Peace’, True]

# %%
series = pd.Series(['Love', 800, 'Joy', 789.9, 'Peace', True])

series.to_list()
# Out:
# ['Love', 800, 'Joy', 789.9, 'Peace', True]

# %% [markdown]
# # 5.	Write a Pandas program to display the most frequent value in the given series and replace everything else as ‘Other’ in the series. (Use the ‘HomeTeamGoals’ column in the dataset provided)

# %%
df = pd.read_csv("./AfricaCupofNationsMatches.csv")

home_team_goals = df['HomeTeamGoals']

# %%
mode = home_team_goals.mode()[0]
mode
# Out:
# 1.0

# %%
home_team_goals[home_team_goals != mode] = "Other"
home_team_goals
# Out:
# C:\Users\dex\AppData\Local\Temp\ipykernel_9000\1881283424.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   home_team_goals[home_team_goals != mode] = "Other"
# 0        1.0
# 1      Other
# 2      Other
# 3      Other
# 4        1.0
#        ...
# 617    Other
# 618      1.0
# 619    Other
# 620    Other
# 621    Other
# Name: HomeTeamGoals, Length: 622, dtype: object

# %% [markdown]
# # 1.	Write a Pandas program to read the given csv file.

# %%
df = pd.read_csv("./AfricaCupofNationsMatches.csv")

# %%
#2.	Write a Pandas program to get the first 7 rows of your data frame.

df.head(n = 7)
# Out:
#    Year      Date  Time    HomeTeam       AwayTeam  HomeTeamGoals  \
# 0  1957  10-Feb-57   NaN     Sudan           Egypt            1.0
# 1  1957  10-Feb-57   NaN  Ethiopia    South Africa            NaN
# 2  1957  16-Feb-57   NaN     Egypt        Ethiopia            4.0
# 3  1959  22-May-59   NaN      Egypt       Ethiopia            4.0
# 4  1959  25-May-59   NaN     Sudan        Ethiopia            1.0
# 5  1959  29-May-59   NaN      Egypt          Sudan            2.0
# 6  1962  14-Jan-62   NaN  Ethiopia         Tunisia            4.0
#
#    AwayTeamGoals             Stage  \
# 0            2.0        Semifinals
# 1            NaN        Semifinals
# 2            0.0             Final
# 3            0.0  Final Tournament
# 4            0.0  Final Tournament
# 5            1.0  Final Tournament
# 6            2.0        Semifinals
#
#                                 SpecialWinConditions                 Stadium  \
# 0                                                NaN       Municipal Stadium
# 1  Ethiopia  wins due to disqualification of othe...                     NaN
# 2                                                NaN       Municipal Stadium
# 3                                                NaN   Prince Farouk Stadium
# 4                                                NaN   Prince Farouk Stadium
# 5                                                NaN   Prince Farouk Stadium
# 6                                                NaN  Hailé Sélassié Stadium
#
#            City  Attendance
# 0      Khartoum     30000.0
# 1           NaN         NaN
# 2      Khartoum     30000.0
# 3         Cairo     30000.0
# 4         Cairo     20000.0
# 5         Cairo     30000.0
# 6   Addis Ababa     30000.0

# %% [markdown]
# # 3.	Write a Pandas program to select the ‘HomeTeam’, ‘AwayTeam’, ‘HomeTeamGoals’ and ‘AwayTeamGoals’ columns from your data frame.

# %%
new_df = df[["HomeTeam", "AwayTeam", "HomeTeamGoals", "AwayTeamGoals"]]
new_df.head()
# Out:
#     HomeTeam       AwayTeam  HomeTeamGoals  AwayTeamGoals
# 0     Sudan           Egypt            1.0            2.0
# 1  Ethiopia    South Africa            NaN            NaN
# 2     Egypt        Ethiopia            4.0            0.0
# 3      Egypt       Ethiopia            4.0            0.0
# 4     Sudan        Ethiopia            1.0            0.0

# %% [markdown]
# # 4.	Write a Pandas program to select the rows where Egypt appears.

# %%
df[df == "Egypt"]
# Out:
#      Year Date  Time  HomeTeam AwayTeam  HomeTeamGoals  AwayTeamGoals Stage  \
# 0     NaN   NaN   NaN      NaN      NaN            NaN            NaN   NaN
# 1     NaN   NaN   NaN      NaN      NaN            NaN            NaN   NaN
# 2     NaN   NaN   NaN      NaN      NaN            NaN            NaN   NaN
# 3     NaN   NaN   NaN    Egypt      NaN            NaN            NaN   NaN
# 4     NaN   NaN   NaN      NaN      NaN            NaN            NaN   NaN
# ..    ...   ...   ...      ...      ...            ...            ...   ...
# 617   NaN   NaN   NaN      NaN      NaN            NaN            NaN   NaN
# 618   NaN   NaN   NaN      NaN      NaN            NaN            NaN   NaN
# 619   NaN   NaN   NaN      NaN      NaN            NaN            NaN   NaN
# 620   NaN   NaN   NaN      NaN      NaN            NaN            NaN   NaN
# 621   NaN   NaN   NaN      NaN      NaN            NaN            NaN   NaN
#
#     SpecialWinConditions Stadium City  Attendance
# 0                    NaN     NaN  NaN         NaN
# 1                    NaN     NaN  NaN         NaN
# 2                    NaN     NaN  NaN         NaN
# 3                    NaN     NaN  NaN         NaN
# 4                    NaN     NaN  NaN         NaN
# ..                   ...     ...  ...         ...
# 617                  NaN     NaN  NaN         NaN
# 618                  NaN     NaN  NaN         NaN
# 619                  NaN     NaN  NaN         NaN
# 620                  NaN     NaN  NaN         NaN
# 621                  NaN     NaN  NaN         NaN
#
# [622 rows x 12 columns]

# %% [markdown]
# # 5.	Write a Pandas program to count the number of rows and columns of your data frame.

# %%
rows = df.shape[0]
columns = df.shape[1]

rows, columns
# Out:
# (622, 12)

# %% [markdown]
# # 6.	Write a Pandas program to select the rows where the ‘Attendance’ is missing.

# %%
df[df != "Attendance"]
# Out:
#      Year                      Date   Time      HomeTeam       AwayTeam  \
# 0    1957                  10-Feb-57    NaN       Sudan           Egypt
# 1    1957                  10-Feb-57    NaN    Ethiopia    South Africa
# 2    1957                  16-Feb-57    NaN       Egypt        Ethiopia
# 3    1959                  22-May-59    NaN        Egypt       Ethiopia
# 4    1959                  25-May-59    NaN       Sudan        Ethiopia
# ..    ...                        ...    ...          ...            ...
# 617  2019  11 July 2019 (2019-07-11)  21:00  Madagascar         Tunisia
# 618  2019  14 July 2019 (2019-07-14)  18:00     Senegal         Tunisia
# 619  2019  14 July 2019 (2019-07-14)  21:00     Algeria         Nigeria
# 620  2019  17 July 2019 (2019-07-17)  21:00     Tunisia         Nigeria
# 621  2019  19 July 2019 (2019-07-19)  21:00     Senegal         Algeria
#
#      HomeTeamGoals  AwayTeamGoals                 Stage  \
# 0              1.0            2.0            Semifinals
# 1              NaN            NaN            Semifinals
# 2              4.0            0.0                 Final
# 3              4.0            0.0      Final Tournament
# 4              1.0            0.0      Final Tournament
# ..             ...            ...                   ...
# 617            0.0            3.0        Quarter-finals
# 618            1.0            0.0           Semi-finals
# 619            2.0            1.0           Semi-finals
# 620            0.0            1.0  Third place play-off
# 621            0.0            1.0                 Final
#
#                                   SpecialWinConditions  \
# 0                                                  NaN
# 1    Ethiopia  wins due to disqualification of othe...
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 617                                                NaN
# 618                              win after extra time
# 619                                                NaN
# 620                                                NaN
# 621                                                NaN
#
#                          Stadium       City  Attendance
# 0              Municipal Stadium   Khartoum     30000.0
# 1                            NaN        NaN         NaN
# 2              Municipal Stadium   Khartoum     30000.0
# 3          Prince Farouk Stadium      Cairo     30000.0
# 4          Prince Farouk Stadium      Cairo     20000.0
# ..                           ...        ...         ...
# 617             Al Salam Stadium      Cairo      7568.0
# 618              30 June Stadium      Cairo      9143.0
# 619  Cairo International Stadium      Cairo     49775.0
# 620             Al Salam Stadium      Cairo      6340.0
# 621  Cairo International Stadium      Cairo     75000.0
#
# [622 rows x 12 columns]

# %% [markdown]
# # 7.	Write a Pandas program to select the rows where the ‘HomeTeamGoals’ are between 3 and 6 inclusive.

# %%
df.loc[df['HomeTeamGoals'].between(3, 6)]
# Out:
#      Year                         Date   Time    HomeTeam     AwayTeam  \
# 2    1957                     16-Feb-57    NaN     Egypt      Ethiopia
# 3    1959                     22-May-59    NaN      Egypt     Ethiopia
# 6    1962                     14-Jan-62    NaN  Ethiopia       Tunisia
# 8    1962                     20-Jan-62    NaN   Tunisia        Uganda
# 9    1962                     21-Jan-62    NaN  Ethiopia         Egypt
# ..    ...                           ...    ...        ...          ...
# 553  2017  20 January 2017 (2017-01-20)  20:00   Morocco          Togo
# 585  2019     27 June 2019 (2019-06-27)  22:00     Kenya      Tanzania
# 595  2019     24 June 2019 (2019-06-24)  22:00      Mali    Mauritania
# 608  2019      6 July 2019 (2019-07-06)  18:00   Nigeria      Cameroon
# 611  2019      7 July 2019 (2019-07-07)  21:00   Algeria        Guinea
#
#      HomeTeamGoals  AwayTeamGoals              Stage    SpecialWinConditions  \
# 2              4.0            0.0              Final                     NaN
# 3              4.0            0.0   Final Tournament                     NaN
# 6              4.0            2.0         Semifinals                     NaN
# 8              3.0            0.0  Third place match                     NaN
# 9              4.0            2.0              Final   win after extra time
# ..             ...            ...                ...                     ...
# 553            3.0            1.0            Group C                     NaN
# 585            3.0            2.0            Group C                     NaN
# 595            4.0            1.0            Group E                     NaN
# 608            3.0            2.0        Round of 16                     NaN
# 611            3.0            0.0        Round of 16                     NaN
#
#                     Stadium          City  Attendance
# 2         Municipal Stadium      Khartoum     30000.0
# 3     Prince Farouk Stadium         Cairo     30000.0
# 6    Hailé Sélassié Stadium   Addis Ababa     30000.0
# 8    Hailé Sélassié Stadium   Addis Ababa         NaN
# 9    Hailé Sélassié Stadium   Addis Ababa         NaN
# ..                      ...           ...         ...
# 553            Stade d'Oyem          Oyem         NaN
# 585         30 June Stadium         Cairo      7233.0
# 595            Suez Stadium          Suez      6202.0
# 608      Alexandria Stadium    Alexandria     10000.0
# 611         30 June Stadium         Cairo      8205.0
#
# [138 rows x 12 columns]

# %% [markdown]
# # 8.	Write a Pandas program to change the “AwayTeamGoals” in the 3rd row to 10.

# %%
df["AwayTeamGoals"].iloc[2] = 10
df["AwayTeamGoals"].head()
# Out:
# C:\Users\dex\AppData\Local\Temp\ipykernel_9000\1661745429.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["AwayTeamGoals"].iloc[2] = 10
# 0     2.0
# 1     NaN
# 2    10.0
# 3     0.0
# 4     0.0
# Name: AwayTeamGoals, dtype: float64

# %% [markdown]
# # 9.	Write a Pandas program to sort the DataFrame first by ‘HomeTeam’ in ascending order, then by ‘HomeTeamScores’ in descending order.

# %%
sort1 = df.sort_values("HomeTeam", ascending=True)
sort1
# Out:
#      Year                         Date   Time    HomeTeam   AwayTeam  \
# 403  2004                      3-Feb-04  14:00   Algeria    Zimbabwe
# 229  1992                     17-Jan-92    NaN   Algeria       Congo
# 291  1998                      8-Feb-98  20:30   Algeria      Guinea
# 544  2017  15 January 2017 (2017-01-15)  17:00   Algeria    Zimbabwe
# 148  1982                      7-Mar-82    NaN   Algeria      Zambia
# ..    ...                           ...    ...        ...        ...
# 230  1992                     13-Jan-92    NaN    Zambia       Egypt
# 575  2019     30 June 2019 (2019-06-30)  21:00  Zimbabwe    DR Congo
# 437  2006                     23-Jan-06  20:00  Zimbabwe     Senegal
# 549  2017  23 January 2017 (2017-01-23)  20:00  Zimbabwe     Tunisia
# 398  2004                     25-Jan-04  16:30  Zimbabwe       Egypt
#
#      HomeTeamGoals  AwayTeamGoals    Stage SpecialWinConditions  \
# 403            1.0            2.0  Group C                  NaN
# 229            1.0            1.0  Group C                  NaN
# 291            0.0            1.0  Group A                  NaN
# 544            2.0            2.0  Group B                  NaN
# 148            1.0            0.0  Group B                  NaN
# ..             ...            ...      ...                  ...
# 230            1.0            0.0  Group D                  NaN
# 575            0.0            4.0  Group A                  NaN
# 437            0.0            2.0  Group D                  NaN
# 549            2.0            4.0  Group B                  NaN
# 398            1.0            2.0  Group C                  NaN
#
#                        Stadium          City  Attendance
# 403  Stade Olympique de Sousse        Sousse     10000.0
# 229   Stade Aline Sitoe Diatta    Ziguinchor      5000.0
# 291            Stade Municipal   Ouagadougou      3000.0
# 544       Stade de Franceville   Franceville         NaN
# 148           28 March Stadium      Benghazi      5000.0
# ..                         ...           ...         ...
# 230   Stade Aline Sitoe Diatta    Ziguinchor      5000.0
# 575            30 June Stadium         Cairo      4364.0
# 437          Port Said Stadium     Port Said     15000.0
# 549          Stade de l'Amitié    Libreville         NaN
# 398       Stade Taïeb El Mhiri          Sfax     22000.0
#
# [622 rows x 12 columns]

# %%
sort2 = df.sort_values("HomeTeamGoals", ascending=False)
sort2
# Out:
#      Year                      Date   Time        HomeTeam  \
# 13   1963                  24-Nov-63    NaN          Egypt
# 46   1970                  10-Feb-70    NaN   Ivory Coast
# 72   1972                   4-Mar-72    NaN      Cameroon
# 21   1965                  12-Nov-65    NaN         Ghana
# 400  2004                  29-Jan-04  16:30      Cameroon
# ..    ...                        ...    ...            ...
# 621  2019  19 July 2019 (2019-07-19)  21:00       Senegal
# 1    1957                  10-Feb-57    NaN      Ethiopia
# 489  2010                  11-Jan-10  19:30         Ghana
# 490  2010                  15-Jan-10  17:00  Burkina Faso
# 493  2010                  19-Jan-10  17:00   Ivory Coast
#
#                  AwayTeam  HomeTeamGoals  AwayTeamGoals              Stage  \
# 13                Nigeria            6.0            3.0            Group B
# 46               Ethiopia            6.0            1.0            Group A
# 72                  Zaire            5.0            2.0  Third place match
# 21    Congo-Léopoldville            5.0            2.0            Group B
# 400              Zimbabwe            5.0            3.0            Group C
# ..                    ...            ...            ...                ...
# 621               Algeria            0.0            1.0              Final
# 1            South Africa            NaN            NaN         Semifinals
# 489                  Togo            NaN            NaN            Group B
# 490                  Togo            NaN            NaN            Group B
# 493                  Togo            NaN            NaN            Group B
#
#                                   SpecialWinConditions  \
# 13                                                 NaN
# 46                                                 NaN
# 72                                                 NaN
# 21                                                 NaN
# 400                                                NaN
# ..                                                 ...
# 621                                                NaN
# 1    Ethiopia  wins due to disqualification of othe...
# 489  Ghana  wins due to disqualification of other team
# 490  Burkina Faso  wins due to disqualification of ...
# 493  Ivory Coast  wins due to disqualification of o...
#
#                          Stadium       City  Attendance
# 13         Kumasi Sports Stadium     Kumasi         NaN
# 46             Municipal Stadium   Khartoum      9770.0
# 72              Stade Omnisports    Yaoundé         NaN
# 21         Stade Bou Ali Lahouar     Sousse         NaN
# 400         Stade Taïeb El Mhiri       Sfax     15000.0
# ..                           ...        ...         ...
# 621  Cairo International Stadium      Cairo     75000.0
# 1                            NaN        NaN         NaN
# 489                          NaN        NaN         NaN
# 490                          NaN        NaN         NaN
# 493                          NaN        NaN         NaN
#
# [622 rows x 12 columns]

# %% [markdown]
# # 10.	Write a Pandas program to get list from DataFrame column headers.

# %%
df.columns
# Out:
# Index(['Year', 'Date ', 'Time ', 'HomeTeam', 'AwayTeam', 'HomeTeamGoals',
#        'AwayTeamGoals', 'Stage', 'SpecialWinConditions', 'Stadium', 'City',
#        'Attendance'],
#       dtype='object')

# %% [markdown]
# # 11.	Write a Pandas program to append a column of your choice to your DataFrame.

# %%
import numpy as np
df["new column"] = np.zeros(len(df))

# %%
df.head()
# Out:
#    Year      Date  Time    HomeTeam       AwayTeam  HomeTeamGoals  \
# 0  1957  10-Feb-57   NaN     Sudan           Egypt            1.0
# 1  1957  10-Feb-57   NaN  Ethiopia    South Africa            NaN
# 2  1957  16-Feb-57   NaN     Egypt        Ethiopia            4.0
# 3  1959  22-May-59   NaN      Egypt       Ethiopia            4.0
# 4  1959  25-May-59   NaN     Sudan        Ethiopia            1.0
#
#    AwayTeamGoals             Stage  \
# 0            2.0        Semifinals
# 1            NaN        Semifinals
# 2           10.0             Final
# 3            0.0  Final Tournament
# 4            0.0  Final Tournament
#
#                                 SpecialWinConditions                Stadium  \
# 0                                                NaN      Municipal Stadium
# 1  Ethiopia  wins due to disqualification of othe...                    NaN
# 2                                                NaN      Municipal Stadium
# 3                                                NaN  Prince Farouk Stadium
# 4                                                NaN  Prince Farouk Stadium
#
#         City  Attendance  new column
# 0   Khartoum     30000.0         0.0
# 1        NaN         NaN         0.0
# 2   Khartoum     30000.0         0.0
# 3      Cairo     30000.0         0.0
# 4      Cairo     20000.0         0.0

# %% [markdown]
# # 12.	Write a Pandas program to add 2 rows to your DataFrame.

# %%
rows = pd.DataFrame(
    [
        df.iloc[0],
        df.iloc[5]
    ]
)

rows
# Out:
#    Year      Date   Time  HomeTeam AwayTeam  HomeTeamGoals  AwayTeamGoals  \
# 0  1957  10-Feb-57    NaN   Sudan     Egypt            1.0            2.0
# 5  1959  29-May-59    NaN    Egypt    Sudan            2.0            1.0
#
#               Stage  SpecialWinConditions                Stadium       City  \
# 0        Semifinals                   NaN      Municipal Stadium   Khartoum
# 5  Final Tournament                   NaN  Prince Farouk Stadium      Cairo
#
#    Attendance  new column
# 0     30000.0         0.0
# 5     30000.0         0.0

# %%
df = pd.concat([df, rows], ignore_index=True)
# Out:
#      Year                      Date   Time    HomeTeam       AwayTeam  \
# 0    1957                  10-Feb-57    NaN     Sudan           Egypt
# 1    1957                  10-Feb-57    NaN  Ethiopia    South Africa
# 2    1957                  16-Feb-57    NaN     Egypt        Ethiopia
# 3    1959                  22-May-59    NaN      Egypt       Ethiopia
# 4    1959                  25-May-59    NaN     Sudan        Ethiopia
# ..    ...                        ...    ...        ...            ...
# 619  2019  14 July 2019 (2019-07-14)  21:00   Algeria         Nigeria
# 620  2019  17 July 2019 (2019-07-17)  21:00   Tunisia         Nigeria
# 621  2019  19 July 2019 (2019-07-19)  21:00   Senegal         Algeria
# 622  1957                  10-Feb-57    NaN     Sudan           Egypt
# 623  1959                  29-May-59    NaN      Egypt          Sudan
#
#      HomeTeamGoals  AwayTeamGoals                 Stage  \
# 0              1.0            2.0            Semifinals
# 1              NaN            NaN            Semifinals
# 2              4.0           10.0                 Final
# 3              4.0            0.0      Final Tournament
# 4              1.0            0.0      Final Tournament
# ..             ...            ...                   ...
# 619            2.0            1.0           Semi-finals
# 620            0.0            1.0  Third place play-off
# 621            0.0            1.0                 Final
# 622            1.0            2.0            Semifinals
# 623            2.0            1.0      Final Tournament
#
#                                   SpecialWinConditions  \
# 0                                                  NaN
# 1    Ethiopia  wins due to disqualification of othe...
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 619                                                NaN
# 620                                                NaN
# 621                                                NaN
# 622                                                NaN
# 623                                                NaN
#
#                          Stadium       City  Attendance  new column
# 0              Municipal Stadium   Khartoum     30000.0         0.0
# 1                            NaN        NaN         NaN         0.0
# 2              Municipal Stadium   Khartoum     30000.0         0.0
# 3          Prince Farouk Stadium      Cairo     30000.0         0.0
# 4          Prince Farouk Stadium      Cairo     20000.0         0.0
# ..                           ...        ...         ...         ...
# 619  Cairo International Stadium      Cairo     49775.0         0.0
# 620             Al Salam Stadium      Cairo      6340.0         0.0
# 621  Cairo International Stadium      Cairo     75000.0         0.0
# 622            Municipal Stadium   Khartoum     30000.0         0.0
# 623        Prince Farouk Stadium      Cairo     30000.0         0.0
#
# [624 rows x 13 columns]

# %% [markdown]
# # 13.	Write a Pandas program to change the country ‘Uganda’ to ‘China’ in the ‘AwayTeam’ column of the DataFrame.

# %%
df["AwayTeam"] = df["AwayTeam"].str.replace("Uganda", "China")

# %%
df["AwayTeam"].unique()
# Out:
# array([' Egypt', ' South Africa', ' Ethiopia', ' Sudan', ' Tunisia',
#        ' China', 'Egypt', ' Nigeria', ' Congo-Léopoldville',
#        ' Ivory Coast', ' Algeria', ' Senegal', ' Congo-Brazzaville',
#        ' Congo-Kinshasa', ' Ghana', ' Cameroon', ' Guinea', ' Kenya',
#        ' Togo', ' Mali', ' Morocco', ' Congo', ' Zaire', ' Zambia',
#        ' Mauritius', ' Upper Volta', ' Tanzania', ' Libya', ' Malawi',
#        ' Mozambique', ' Gabon', ' Sierra Leone', ' Angola',
#        ' Burkina Faso', ' Liberia', ' DR Congo', ' Namibia', ' Rwanda',
#        ' Zimbabwe', ' Benin', ' Equatorial Guinea', ' Cape Verde',
#        ' Guinea-Bissau', ' Burundi', ' Madagascar', ' Mauritania'],
#       dtype=object)

# %% [markdown]
# # 14.	Write a Pandas program to reset index in your DataFrame.

# %%
#reset he index to start from 1
df.index = pd.RangeIndex(start=1, stop=len(df) + 1, step=1)

df.head()
# Out:
#    Year      Date  Time    HomeTeam       AwayTeam  HomeTeamGoals  \
# 1  1957  10-Feb-57   NaN     Sudan           Egypt            1.0
# 2  1957  10-Feb-57   NaN  Ethiopia    South Africa            NaN
# 3  1957  16-Feb-57   NaN     Egypt        Ethiopia            4.0
# 4  1959  22-May-59   NaN      Egypt       Ethiopia            4.0
# 5  1959  25-May-59   NaN     Sudan        Ethiopia            1.0
#
#    AwayTeamGoals             Stage  \
# 1            2.0        Semifinals
# 2            NaN        Semifinals
# 3           10.0             Final
# 4            0.0  Final Tournament
# 5            0.0  Final Tournament
#
#                                 SpecialWinConditions                Stadium  \
# 1                                                NaN      Municipal Stadium
# 2  Ethiopia  wins due to disqualification of othe...                    NaN
# 3                                                NaN      Municipal Stadium
# 4                                                NaN  Prince Farouk Stadium
# 5                                                NaN  Prince Farouk Stadium
#
#         City  Attendance  new column
# 1   Khartoum     30000.0         0.0
# 2        NaN         NaN         0.0
# 3   Khartoum     30000.0         0.0
# 4      Cairo     30000.0         0.0
# 5      Cairo     20000.0         0.0

# %% [markdown]
# # 15.	Write a Pandas program to check whether the ‘Stadium’ column is present in your DataFrame or not

# %%
"Stadium" in df
# Out:
# True

# %% [markdown]
# # 16.	Write a Pandas program to convert the datatype of the ‘AwayTeamGoals’. (int to float)

# %%
df["AwayTeamGoals"] = df["AwayTeamGoals"].astype(float)

# %% [markdown]
# # 17.	Write a Pandas program to remove the last 10 rows from your DataFrame.

# %%
df = df.iloc[:-10]

# %% [markdown]
# # 18.	Write a Pandas program to iterate over rows in your DataFrame.

# %%
#iterate through the firsrt 10 rows
count = 0
for index, row in df.iterrows():
    print(row["HomeTeam"])

    if count > 10:

        break

    count += 1
# Out:
# Sudan
# Ethiopia
# Egypt
# Egypt
# Sudan
# Egypt
# Ethiopia
# Egypt
# Tunisia
# Ethiopia
# Ghana
# Ghana

# %% [markdown]
# # 19.	Write a Pandas program to change the order of your DataFrame columns.

# %%
rev_columns = df.columns[::-1]

rev_columns
# Out:
# Index(['new column', 'Attendance', 'City', 'Stadium', 'SpecialWinConditions',
#        'Stage', 'AwayTeamGoals', 'HomeTeamGoals', 'AwayTeam', 'HomeTeam',
#        'Time ', 'Date ', 'Year'],
#       dtype='object')

# %%
df = df[rev_columns]

df.head()
# Out:
#    new column  Attendance       City                Stadium  \
# 1         0.0     30000.0   Khartoum      Municipal Stadium
# 2         0.0         NaN        NaN                    NaN
# 3         0.0     30000.0   Khartoum      Municipal Stadium
# 4         0.0     30000.0      Cairo  Prince Farouk Stadium
# 5         0.0     20000.0      Cairo  Prince Farouk Stadium
#
#                                 SpecialWinConditions             Stage  \
# 1                                                NaN        Semifinals
# 2  Ethiopia  wins due to disqualification of othe...        Semifinals
# 3                                                NaN             Final
# 4                                                NaN  Final Tournament
# 5                                                NaN  Final Tournament
#
#    AwayTeamGoals  HomeTeamGoals       AwayTeam   HomeTeam Time       Date   \
# 1            2.0            1.0          Egypt     Sudan    NaN  10-Feb-57
# 2            NaN            NaN   South Africa  Ethiopia    NaN  10-Feb-57
# 3           10.0            4.0       Ethiopia     Egypt    NaN  16-Feb-57
# 4            0.0            4.0       Ethiopia      Egypt   NaN  22-May-59
# 5            0.0            1.0       Ethiopia     Sudan    NaN  25-May-59
#
#    Year
# 1  1957
# 2  1957
# 3  1957
# 4  1959
# 5  1959

# %% [markdown]
# # 20.	Write a Pandas program to delete DataFrame row(s) whose value is 0 in the ‘HomeTeamGoals’ columns.

# %%
df = df[df.HomeTeamGoals != 0]

# %%
df.head()
# Out:
#    new column  Attendance       City                Stadium  \
# 1         0.0     30000.0   Khartoum      Municipal Stadium
# 2         0.0         NaN        NaN                    NaN
# 3         0.0     30000.0   Khartoum      Municipal Stadium
# 4         0.0     30000.0      Cairo  Prince Farouk Stadium
# 5         0.0     20000.0      Cairo  Prince Farouk Stadium
#
#                                 SpecialWinConditions             Stage  \
# 1                                                NaN        Semifinals
# 2  Ethiopia  wins due to disqualification of othe...        Semifinals
# 3                                                NaN             Final
# 4                                                NaN  Final Tournament
# 5                                                NaN  Final Tournament
#
#    AwayTeamGoals  HomeTeamGoals       AwayTeam   HomeTeam Time       Date   \
# 1            2.0            1.0          Egypt     Sudan    NaN  10-Feb-57
# 2            NaN            NaN   South Africa  Ethiopia    NaN  10-Feb-57
# 3           10.0            4.0       Ethiopia     Egypt    NaN  16-Feb-57
# 4            0.0            4.0       Ethiopia      Egypt   NaN  22-May-59
# 5            0.0            1.0       Ethiopia     Sudan    NaN  25-May-59
#
#    Year
# 1  1957
# 2  1957
# 3  1957
# 4  1959
# 5  1959
